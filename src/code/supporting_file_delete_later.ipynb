# %%
from dashboard_plots import *

# %%
indicator_value_plot(value='GDP', from_year=2004, end_year = pd.to_datetime(datetime.today().strftime('%Y-%m-%d')).year)

# %%
indicator_growth_path = '../../data/storeddata/GDP_GrowthRateResults.csv'
indicator_growth = pd.read_csv(indicator_growth_path, index_col=0)
indicator_growth.index = pd.to_datetime(indicator_growth.index)
indicator_growth.tail()
# Out:
#             GDP_GrowthRate  Fitted Value  Predicted Value     0.025     0.975  \
# 2021-04-01       -0.007920           NaN         0.010475 -0.006787  0.028335
# 2021-07-01        0.013078           NaN         0.001305 -0.008787  0.022873
# 2021-10-01        0.016026           NaN         0.019263  0.006527  0.033764
# 2022-01-01        0.007550           NaN        -0.003761 -0.016927  0.004236
# 2022-04-01             NaN           NaN         0.010644 -0.004298  0.026677
#
#             Mean (Prediction invertal)
# 2021-04-01                    0.011699
# 2021-07-01                    0.004105
# 2021-10-01                    0.020505
# 2022-01-01                   -0.005709
# 2022-04-01                    0.011570
